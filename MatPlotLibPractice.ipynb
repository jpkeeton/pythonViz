# %%
# from DataCamp: https://campus.datacamp.com/courses/introduction-to-data-science-in-python/plotting-data-with-matplotlib?ex=2

# From matplotlib, import pyplot under the alias plt
from matplotlib import pyplot as plt

# Plot Officer Deshaun's hours_worked vs. day_of_week
# so plot CREATES the plot
plt.plot(deshaun.day_of_week, deshaun.hours_worked)

# Display Deshaun's plot
# and show DISPLAYS the plot
plt.show()




# Another example:
# Plot Officer Deshaun's hours_worked vs. day_of_week
plt.plot(deshaun.day_of_week, deshaun.hours_worked)

# Plot Officer Aditya's hours_worked vs. day_of_week
plt.plot(aditya.day_of_week, aditya.hours_worked)

# Plot Officer Mengfei's hours_worked vs. day_of_week
plt.plot(mengfei.day_of_week, mengfei.hours_worked)

# Display all three line plots
plt.show()

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
# So for this, I MUST run the imports ave
Image("C:/Users/jpkee/Pictures/DataVizResources/MatPlotLibSytaxExample1.png")
#here 'ransom' is the name of the dataframe

# %%
Image("C:/Users/jpkee/Pictures/DataVizResources/MatPlotLibSytaxExample2.png")

# %% [markdown]
# Labels
# * read as 'plt.xlabel', or 'plt.ylabel'
# * as in 'plt.xlabel("this is a label")'
#
# * plt.txt(x, y and text as string)
# * plt.legend() nothing needed
# * here is how to add text to specific coordinates in the plt
#     * plt.text(2.5, 80, "Missing June data")

# %%
# >>> plot(a[0], a[1:]) 
# can be used for arrays! 
# This is what I was going to start looking for

# %%
# Change the color of Phoenix to `"DarkCyan"`
plt.plot(data["Year"], data["Phoenix Police Dept"], label="Phoenix", color = "DarkCyan")

# Make the Los Angeles line dotted
plt.plot(data["Year"], data["Los Angeles Police Dept"], label="Los Angeles", linestyle = ':')

# Add square markers to Philedelphia
plt.plot(data["Year"], data["Philadelphia Police Dept"], label="Philadelphia", marker = 's')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# here you can close and clear the plot, need more practice w that
# plt.close()
# plt.clf()

# %%
# Plot each line
plt.plot(ransom.letter, ransom.frequency,
         label='Ransom', linestyle=':', color='gray')

# X-values should be suspect1.letter
# Y-values should be suspect1.frequency
# Label should be "Fred Frequentist"
plt.plot(suspect1.letter, suspect1.frequency, label="Fred Frequentist")

# Display the plot
plt.show()

# %%
# Plot each line
plt.plot(ransom.letter, ransom.frequency,
         label='Ransom', linestyle=':', color='gray')
plt.plot(suspect1.letter, suspect1.frequency, label='Fred Frequentist')
plt.plot(suspect2.letter, suspect2.frequency, label='Gertrude Cox')

# Add x- and y-labels
plt.xlabel("Letter")
plt.ylabel("Frequency")

# Add a legend
plt.legend()

# Display plot
plt.show()

# %% [markdown]
# **Scatter Plots**

# %%
Image("C:/Users/jpkee/Pictures/DataVizResources/MatPlotLibSytaxScatterPlots.png")

# %%
# Explore the data, get top 5 rows
print(cellphone.head())

# # Create a scatter plot of the data from the DataFrame cellphone
plt.scatter(cellphone.x, cellphone.y)

# # Add labels
plt.ylabel('Latitude')
plt.xlabel('Longitude')

# # Display the plot
plt.show()

# %%
# Change the transparency to 0.1
plt.scatter(cellphone.x, cellphone.y,
           color='red',
           marker='s',
           alpha=0.1)

# Add labels
plt.ylabel('Latitude')
plt.xlabel('Longitude')

# Display the plot
plt.show()

# %% [markdown]
# **Stacked Bars**

# %%
Image("C:/Users/jpkee/Pictures/DataVizResources/MatPlotLibSytaxStackedBars.png")

# %%
# Display the DataFrame hours using print
print(hours)

# Create a bar plot from the DataFrame hours
plt.bar(hours.officer, hours.avg_hours_worked)

# Display the plot
plt.show()

# %%
# error bars, why are they called error bars?
# Display the DataFrame hours using print
print(hours)

# Create a bar plot from the DataFrame hours
plt.bar(hours.officer, hours.avg_hours_worked,
        # Add error bars
        yerr=hours.std_hours_worked)

# Display the plot
plt.show()

# %%
# Plot the number of hours spent on desk work
plt.bar(hours.officer, hours.desk_work, label = "Desk Work")

# Display the plot
plt.show()

# %%
# Plot the number of hours spent on desk work
plt.bar(hours.officer, hours.desk_work, label='Desk Work')

# Plot the hours spent on field work on top of desk work
plt.bar(, label = "Field Work")

# Add a legend
____

# Display the plot
plt.show()

# %%
# More Stacked bar
# Plot the number of hours spent on desk work
plt.bar(hours.officer, hours.desk_work, label='Desk Work')

# Plot the hours spent on field work on top of desk work
plt.bar(hours.officer, hours.field_work,
        bottom=hours.desk_work, label='Field Work')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# **Histograms**

# %%
Image("C:/Users/jpkee/Pictures/DataVizResources/MatPlotLibSytaxHistogram.png")

# %%
# Create a histogram of the column weight
# from the DataFrame puppies
plt.hist(puppies.weight)

# Add labels
plt.xlabel('Puppy Weight (lbs)')
plt.ylabel('Number of Puppies')

# Display
plt.show()

# %%
# Change the range to start at 5 and end at 35
plt.hist(puppies.weight,
        range=(5, 35))

# Add labels
plt.xlabel('Puppy Weight (lbs)')
plt.ylabel('Number of Puppies')

# Display
plt.show()

# %%
# Create a histogram
# Range is 2 to 8, with 40 bins
plt.hist(gravel.radius, bins = 40, range=(2, 8))


# Display histogram
plt.show()

# %%
# Density, woops, was trying to put the boolean in "", duh
# Create a histogram
# Normalize to 1
plt.hist(gravel.radius,
         bins=40,
         range=(2, 8),
         density=True)

# Display histogram
plt.show()

# %%
# # https://campus.datacamp.com/courses/introduction-to-data-science-in-python/plotting-data-with-matplotlib?ex=10
# # Choose any of the styles
# https://matplotlib.org/3.1.1/gallery/style_sheets/style_sheets_reference.html
# plt.style.use("tableau-colorblind10")

# # Plot lines
# plt.plot(data["Year"], data["Phoenix Police Dept"], label="Phoenix")
# plt.plot(data["Year"], data["Los Angeles Police Dept"], label="Los Angeles")
# plt.plot(data["Year"], data["Philadelphia Police Dept"], label="Philadelphia")

# # Add a legend
# plt.legend()

# # Display the plot
# plt.show()

# %%
# Get all the styles!
print(plt.style.available)
# Out:
# ['bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-bright', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-darkgrid', 'seaborn-deep', 'seaborn-muted', 'seaborn-notebook', 'seaborn-paper', 'seaborn-pastel', 'seaborn-poster', 'seaborn-talk', 'seaborn-ticks', 'seaborn-white', 'seaborn-whitegrid', 'seaborn', 'Solarize_Light2', 'tableau-colorblind10', '_classic_test']

# %%
# https://campus.datacamp.com/courses/introduction-to-data-science-in-python/plotting-data-with-matplotlib?ex=10
Image("C:/Users/jpkee/Pictures/DataVizResources/MatPlotLibSytaxExample1Styles.png")
# see also 'plt.style.use("seaborn-dark")'  below
# see more styles here: https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# from this tutorial: https://matplotlib.org/matplotblog/posts/matplotlib-cyberpunk-style/


import matplotlib.pyplot as plt

df = pd.DataFrame({'A': [1, 3, 9, 5, 2, 1, 1],
                   'B': [4, 5, 5, 7, 9, 8, 6]})
plt.style.use("seaborn-dark")

df.plot(marker='o')
plt.show()

# %%
# so here I want to analyze this NBA data
import pandas as pd
from matplotlib import pyplot as plt
nbaData = pd.read_csv("NBA 2018-19 Season.csv")

# %%
nbaData.head()
# Out:
#   Conference  Division            Team         Player  Age  Games  \
# 0    Eastern  Atlantic  Boston Celtics   Jayson Tatum   20     79
# 1    Eastern  Atlantic  Boston Celtics   Kyrie Irving   26     67
# 2    Eastern  Atlantic  Boston Celtics   Marcus Smart   24     80
# 3    Eastern  Atlantic  Boston Celtics  Marcus Morris   29     75
# 4    Eastern  Atlantic  Boston Celtics     Al Horford   32     68
#
#    Games Started  Minutes Played  Field Goals  Field Goal Attempts  ...  \
# 0             79            2455          466                 1036  ...
# 1             67            2214          604                 1241  ...
# 2             60            2200          239                  567  ...
# 3             53            2091          377                  844  ...
# 4             68            1973          387                  723  ...
#
#    Free Throw Percentage  Offensive Rebounds  Defensive Rebounds  \
# 0                  0.855                  70                 407
# ...

# %%
plt.scatter(nbaData.Games, nbaData.Age, label = "NBA Stats")
plt.legend()
plt.show()

# %%
plt.bar(nbaData.Games, nbaData.Age, label = "Games & Ages")
plt.xlabel('Games')
plt.ylabel('Age')
plt.legend()
# Display the plot
plt.show()

# %%
plt.hist(nbaData.Age, bins = 20, rwidth=.9)
plt.style.use("seaborn-dark")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


x = np.arange(0.0, 50.0, 2.0)
y = x ** 1.3 + np.random.rand(*x.shape) * 30.0
s = np.random.rand(*x.shape) * 800 + 500

plt.scatter(x, y, s, c="g", alpha=0.5, marker=r'$\clubsuit$',
            label="Luck")
plt.xlabel("Leprechauns")
plt.ylabel("Gold")
plt.legend(loc='upper left')
plt.show()

# %%
#bar chart example from DataCamp
plt.bar(hours.officer, hours.avg_hours_worked,
        # Add error bars
        yerr=hours.std_hours_worked)

# Display the plot
plt.show()

plt.plot(data["Year"], data["Phoenix Police Dept"], label="Phoenix", color = "DarkCyan")

# %% [markdown]
# More Histograms -
#
# https://www.datacamp.com/community/tutorials/histograms-matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# https://matplotlib.org/3.2.1/gallery/style_sheets/dark_background.html
plt.style.use("dark_background")

for param in ['text.color', 'axes.labelcolor', 'xtick.color', 'ytick.color']:
    plt.rcParams[param] = '0.9'  # very light grey

for param in ['figure.facecolor', 'axes.facecolor', 'savefig.facecolor']:
    plt.rcParams[param] = '#212946'  # bluish dark grey

colors = [
    '#08F7FE',  # teal/cyan
    '#FE53BB',  # pink
    '#F5D300',  # yellow
    '#00ff41',  # matrix green
]


df = pd.DataFrame({'A': [1, 3, 9, 5, 2, 1, 1],
                   'B': [4, 5, 5, 7, 9, 8, 6]})

fig, ax = plt.subplots()

df.plot(marker='o', color=colors, ax=ax)

# Redraw the data with low alpha and slighty increased linewidth:
n_shades = 10
diff_linewidth = 1.05
alpha_value = 0.3 / n_shades

for n in range(1, n_shades+1):

    df.plot(marker='o',
            linewidth=2+(diff_linewidth*n),
            alpha=alpha_value,
            legend=False,
            ax=ax,
            color=colors)

# Color the areas below the lines:
for column, color in zip(df, colors):
    ax.fill_between(x=df.index,
                    y1=df[column].values,
                    y2=[0] * len(df),
                    color=color,
                    # this is the shade/tint of the fill                   
                    alpha=0.1)
# this is the grid color
ax.grid(color='#2A3459')

ax.set_xlim([ax.get_xlim()[0] - 0.2, ax.get_xlim()[1] + 0.2])  # to not have the markers cut off
ax.set_ylim(0)

plt.show()

# %%
# CheatSheet
# more here: https://github.com/matplotlib/cheatsheets
Image("C:/Users/jpkee/Desktop/PythonProjects/Pictures/MatPlotLibCheatSheet.jpg")

# %%
import pandas as pd
import matplotlib.pyplot as plt
df  = pd.read_csv("C:/Users/jpkee/Documents/My Tableau Repository/Datasources/irisData.csv")
# df.plot()  # plots all columns against index
# df.plot(kind='scatter',x='x',y='y') # scatter plot
# df.plot(kind='density')  # estimate density function
# df.plot(kind='hist')  # histogram

# %%
from sklearn import datasets
import pandas as pd

# Load some data
iris = datasets.load_iris()
iris_df = pd.DataFrame(iris['data'], columns=iris['feature_names'])
iris_df['species'] = iris['target']

colours = ['red', 'orange', 'blue']
species = ['I. setosa', 'I. versicolor', 'I. virginica']

for i in range(0, 3):    
    species_df = iris_df[iris_df['species'] == i]    
    plt.scatter(        
        species_df['sepal length (cm)'],        
        species_df['petal length (cm)'],
        color=colours[i],        
        alpha=0.5,        
        label=species[i]   
    )

plt.xlabel('sepal length (cm)')
plt.ylabel('petal length (cm)')
plt.title('Iris dataset: petal length vs sepal length')
plt.legend(loc='lower right')

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
iris = sns.load_dataset("iris")
iris["ID"] = iris.index
iris["ratio"] = iris["sepal_length"]/iris["sepal_width"]

sns.lmplot(x="ID", y="ratio", data=iris, hue="species", fit_reg=False, legend=False)

plt.legend()
plt.show()
